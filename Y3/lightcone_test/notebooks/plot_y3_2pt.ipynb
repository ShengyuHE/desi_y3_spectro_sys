# %% [markdown]
# Plot the BAO signal

# %%
import os
os.environ["MPICH_GPU_SUPPORT_ENABLED"] = "0"
import sys
import glob
import fitsio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.table import Table, vstack

from matplotlib.lines import Line2D
from matplotlib.ticker import ScalarFormatter, NullFormatter
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['legend.fontsize'] = 12
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

from pycorr import TwoPointCorrelationFunction
from pycorr import project_to_multipoles, project_to_wp
from pypower import CatalogFFTPower, PowerSpectrumMultipoles

sys.path.append('/global/homes/s/shengyu/project_rc/main/Y3/')
from helper import REDSHIFT_VSMEAR, Y3_NRAN, Y3_ZRANGE, select_region, sky_to_cartesian

# %%
corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/DA2/Abacus_v4_1/altmtl0/kibo-v1/mock0/LSScats/xi/smu/allcounts_LRG_SGC_z0.4-0.6_default_lin_nran8_split20.npy'
# corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/smu/allcounts_ELG_LOPnotqso_NGC_1.1_1.6_default_FKP_lin_njack0_nran10_split20.npy'
corr = TwoPointCorrelationFunction.load(corr_fn)
s,xi = project_to_multipoles(corr, ells=[0,2])
plt.plot(s,s**2*xi[0], label = 'LRG nsplit=20')
plt.xlabel('s')
plt.ylabel(r'$\xi_0$')

corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/DA2/Abacus_v4_1/altmtl0/kibo-v1/mock0/LSScats/xi/smu/allcounts_LRG_SGC_z0.4-0.6_default_lin_nran8_split10.npy'
# corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/smu/allcounts_ELG_LOPnotqso_NGC_1.1_1.6_default_FKP_lin_njack0_nran10_split20.npy'
corr = TwoPointCorrelationFunction.load(corr_fn)
s,xi = project_to_multipoles(corr, ells=[0,2])
plt.plot(s,s**2*xi[0], label = 'LRG nsplit=10')
# plt.plot(s,s**2*xi[1]-s)


corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/DA2/Abacus_v4_1/altmtl0/kibo-v1/mock0/LSScats/xi/smu/allcounts_LRG_SGC_z0.4-0.6_default_lin_nran8_split5.npy'
# corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/smu/allcounts_ELG_LOPnotqso_NGC_1.1_1.6_default_FKP_lin_njack0_nran10_split20.npy'
corr = TwoPointCorrelationFunction.load(corr_fn)
s,xi = project_to_multipoles(corr, ells=[0,2])
plt.plot(s,s**2*xi[0], label = 'LRG nsplit=5')
# plt.plot(s,s**2*xi[1]-s)

corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/DA2/Abacus_v4_1/altmtl0/kibo-v1/mock0/LSScats/xi/smu/allcounts_LRG_SGC_z0.4-0.6_default_lin_nran8_split2.npy'
# corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/smu/allcounts_ELG_LOPnotqso_NGC_1.1_1.6_default_FKP_lin_njack0_nran10_split20.npy'
corr = TwoPointCorrelationFunction.load(corr_fn)
s,xi = project_to_multipoles(corr, ells=[0,2])
plt.plot(s,s**2*xi[0], label = 'LRG nsplit=2')
# plt.plot(s,s**2*xi[1]-s)

corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/DA2/Abacus_v4_1/altmtl0/kibo-v1/mock0/LSScats/xi/smu/allcounts_LRG_SGC_z0.4-0.6_default_lin_nran8_split1.npy'
# corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/smu/allcounts_ELG_LOPnotqso_NGC_1.1_1.6_default_FKP_lin_njack0_nran10_split20.npy'
corr = TwoPointCorrelationFunction.load(corr_fn)
s,xi = project_to_multipoles(corr, ells=[0,2])
plt.plot(s,s**2*xi[0], label = 'LRG nsplit=1')
# plt.plot(s,s**2*xi[1]-s)

corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/DA2/Abacus_v4_1/altmtl0/kibo-v1/mock0/LSScats/xi/smu/allcounts_ELG_LOPnotqso_SGC_z0.8-1.1_default_lin_nran10_split20.npy'
# corr_fn = '/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/smu/allcounts_ELG_LOPnotqso_NGC_1.1_1.6_default_FKP_lin_njack0_nran10_split20.npy'
corr = TwoPointCorrelationFunction.load(corr_fn)
s,xi = project_to_multipoles(corr, ells=[0,2])
plt.plot(s,s**2*xi[0], label = 'ELG nsplit=20')
plt.xlabel('s')
plt.ylabel(r'$s^2*\xi_0$')
plt.ylim([-60,200])
plt.legend()
