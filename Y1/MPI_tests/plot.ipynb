# %%
# loading the desilike enviroment
import os
import glob
import numpy as np
from astropy.io import fits
from matplotlib import pyplot as plt

plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['legend.fontsize'] = 14
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
no_MPI = 15.080408
MPIn2 = 12.602272
MPIn3 = 8.659879
MPIn4 = 7.337554
MPIn5 = 5.388623
MPIn6 = 4.936591
MPIn7 = 3.565875
MPIn8 = 3.15432
MPIn9= 2.965541

# %%
MPIs = [MPIn2, MPIn3, MPIn4]
nodes = np.arange((len(MPIs)))+2

plt.axhline(y=no_MPI, color='black', linestyle='--', label='No MPI')
plt.errorbar(nodes, MPIs,yerr=1, fmt='o',label='with MPI')
plt.legend()
plt.xlabel('ntasks')
plt.ylabel('running time (s)')
plt.ylim([0,15])

# plt.text(3, 240,'len(job)=4',fontsize=15)
# Out:
# (0.0, 15.0)
