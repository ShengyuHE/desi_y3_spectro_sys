# %% [markdown]
# ## 2-Points Statistics

# %%
# loading the desilike enviroment
import os
os.environ["MPICH_GPU_SUPPORT_ENABLED"] = "0"
import glob
import numpy as np
from astropy.io import fits
from matplotlib import pyplot as plt

from cosmoprimo.fiducial import DESI
from desilike.theories.galaxy_clustering import DirectPowerSpectrumTemplate, ShapeFitPowerSpectrumTemplate, StandardPowerSpectrumTemplate
from desilike.theories.galaxy_clustering import FOLPSTracerPowerSpectrumMultipoles, LPTVelocileptorsTracerPowerSpectrumMultipoles
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from desilike import plotting
from desilike import setup_logging
setup_logging()

plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['legend.fontsize'] = 14
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# the tracers for DESI mocks
tracers = {
    'ELG_lowz': {
        'tracer': 'ELG_LOPnotqso',
        'zmin': 0.8,
        'zmax': 1.1,
        'zeff': 0.98,
        'ran_mock_num': 10
    },
    'ELG_highz': {
        'tracer': 'ELG_LOPnotqso',
        'zmin': 1.1,
        'zmax': 1.6,
        'zeff': 1.325,
        'ran_mock_num': 10
    },
}

# %%
MOCKNUM = 0
survey  ='Y1'
specver ='iron'
mockver ='v4_2'
tracer_type = 'ELG_lowz' # 'ELG_lowz', 'ELG_highz', 
region = "GCcomb"  # NGC, SGC or GCcomb

if tracer_type in tracers:
    settings = tracers[tracer_type]
    tracer = settings['tracer']
    zmin = settings['zmin']
    zmax = settings['zmax']
    zeff = settings['zeff']
    ran_mock_num = settings['ran_mock_num']
else:
    raise ValueError(f"Unknown ztype: {tracer_type}")

pk_dir = f'/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/'
cov_dir = f'/global/cfs/cdirs/desi/survey/catalogs/{survey}/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/'

# load the covariance matrix from the Ezmocks
cov_fns = []
cov_fn = f'pkpoles_ELG_LOP_{region}_z{zmin}-{zmax}_default_FKP_lin_nran10_cellsize6_boxsize9000.npy'
for i in range(0, 500):
    mock_dir = f'mock{i}/pk/'
    cov_fns.extend(glob.glob(os.path.join(cov_dir,  mock_dir, cov_fn), recursive=True))

# %%
# # set the k bins
# kmin     = 0.02
# kmax     = 0.205
# binning  = 0.005
# k_ev     = np.arange(kmin, kmax, binning)
# klen     = len(k_ev)
# klim     = {ell*2: (kmin,kmax,binning) for ell in range(2)}

# set the k bins
kmin     = 0.0225
kmax     = 0.3
binning  = 0.005
k_ev     = np.arange(kmin, kmax, binning)
klen     = len(k_ev)
klim     = {ell*2: (kmin,kmax,binning) for ell in range(2)}

catas_types = ['','_realistic', '_failures']
catas_type = ''

# load the pk file, the pk calculated from the pkrun.py
pk_fn = pk_dir+f'pkpoles_{tracer}_{region}_{zmin}_{zmax}_default_FKP_lin_thetacut0.05{catas_type}.npy'
wmatrix_fn = pk_dir+f'wmatrix_smooth_{tracer}_{region}_{zmin}_{zmax}_default_FKP_lin_thetacut0.05{catas_type}.npy'

cosmo = DESI()
template = DirectPowerSpectrumTemplate(z=zeff,fiducial='DESI')
theory = FOLPSTracerPowerSpectrumMultipoles(template=template)
print(theory.varied_params)
observable = TracerPowerSpectrumMultipolesObservable(data= pk_fn, 
                                                     klim=klim, 
                                                     covariance = cov_fns,
                                                     theory=theory,
                                                     kin=np.arange(0.001, 0.35, 0.002),
                                                     wmatrix=wmatrix_fn)
likelihood = ObservablesGaussianLikelihood(observable, scale_factor = 1/10)
likelihood()
fig_pk = observable.plot()
# Out:
# ParameterCollection(['h', 'omega_cdm', 'omega_b', 'logA', 'b1', 'b2', 'bs', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2'])
# [001887.61] [0/1] 03-05 05:54  TracerPowerSpectrumMultipolesObservable INFO     Loading 1 file ['/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/pkpoles_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy'].
# [001887.66] [0/1] 03-05 05:54  TracerPowerSpectrumMultipolesObservable INFO     Loading 499 files [/global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock1/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock100/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock199/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock298/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock397/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock496/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy].
# [001919.25] [0/1] 03-05 05:55  MeshFFTWindow             INFO     Loading /pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/wmatrix_smooth_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy.
# [001919.31] [0/1] 03-05 05:55  BaseMatrix                INFO     Loading /pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/wmatrix_smooth_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy.
# [001923.52] [0/1] 03-05 05:55  ObservablesGaussianLikelihood INFO     Covariance matrix with 112 points built from 499 observations.
# [001923.52] [0/1] 03-05 05:55  ObservablesGaussianLikelihood INFO     ...resulting in a Hartlap 2007 factor of 0.7731.
# [001926.21] [0/1] 03-05 05:55  ObservablesGaussianLikelihood INFO     Covariance matrix with 112 points built from 499 observations, varying 12 parameters.
# [001926.21] [0/1] 03-05 05:55  ObservablesGaussianLikelihood INFO     ...resulting in a Percival 2014 factor of 1.2191.

# %%
print(likelihood())
# Out:
# -8312.437431179167

# %%
cov = observable.covariance
std = np.sqrt(np.diagonal(cov))

# %%
from desilike.emulators import EmulatedCalculator, Emulator, TaylorEmulatorEngine

cosmology = 'LCDM' #LCDM, nuCDM, wCDM
theory_model = 'FOLPS'  # TNS, FOLPS, FOLPSRC, Velocileptors
emulator_fn = f'./results/emulators/emulator_{cosmology}_z{zeff}_{theory_model}.npy'

def initialize_template(redshift, cosmology):
    cosmo = DESI()
    template = DirectPowerSpectrumTemplate(z=redshift, fiducial='DESI')
    if cosmology == 'nuCDM':
        template.init.params['m_ncdm'].update(fixed=False, latex=r'M_\nu', prior = {'limits': [0.0,1.0]})
    elif cosmology == 'nsCDM':
        template.init.params['n_s'].update(fixed=False)
    elif cosmology == 'wCDM':
        template.init.params['w0_fld'].update(fixed=False)
    return template

# os.remove(emulator_fn)
if not os.path.exists(emulator_fn):
    cosmo = DESI()
    template = initialize_template(zeff, cosmology)
    if theory_model =='Velocileptors':
        theory = LPTVelocileptorsTracerPowerSpectrumMultipoles(template=template, k=k_ev)
    if theory_model =='FOLPS':
        theory = FOLPSTracerPowerSpectrumMultipoles(template=template, k=k_ev)
    elif theory_model =='FOLPSRC':
        theory = FOLPSRCTracerPowerSpectrumMultipoles(template=template, k=k_ev)
    print(theory.varied_params)
    # footprint = BoxFootprint(volume=1e10, nbar=1e-3)
    # covariance = ObservablesCovarianceMatrix(cov_fns, footprints=footprint)()
    observable = TracerPowerSpectrumMultipolesObservable(data= pk_fn, 
                                                        klim=klim, 
                                                        covariance = cov_fns,
                                                        theory = theory,
                                                        kin=np.arange(0.001, 0.35, 0.002),
                                                        wmatrix=wmatrix_fn)
    likelihood = ObservablesGaussianLikelihood(observable)
    likelihood()
    emulator = Emulator(theory.pt, engine=TaylorEmulatorEngine(order=3, method='finite')) # Taylor expansion, up to a given order
    emulator.set_samples() # evaluate the theory derivatives (with jax auto-differentiation if possible, else finite differentiation)
    emulator.fit()
    emulator.save(emulator_fn)
    print("Training emmulator finished")

# %%
if theory_model =='Velocileptors':
    theory_el = LPTVelocileptorsTracerPowerSpectrumMultipoles(pt=EmulatedCalculator.load(emulator_f
able = TracerPowerSpectrumMultipolesObservable(data= pk_fn, 
                                                        klim=klim, 
                                                        covariance = cov_fns,
                                                        theory=theory_el,
                                                        kin=np.arange(0.001, 0.35, 0.002),
                                                        wmatrix=wmatrix_fn)
    likelihood = ObservablesGaussianLikelihood(observable, theory=theory_el)
    likelihood()
    profiler = MinuitProfiler(likelihood, seed=42)
    profiles = profiler.maximize()
    profiles.save(profile_fn)
print("Profiler finished")
profiles = Profiles.load(profile_fn)
print(profiles.to_stats(tablefmt='pretty'))
# Out:
# [000264.62] [0/1] 03-05 05:27  TracerPowerSpectrumMultipolesObservable INFO     Loading 1 file ['/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/pkpoles_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy'].
# [000264.67] [0/1] 03-05 05:27  TracerPowerSpectrumMultipolesObservable INFO     Loading 499 files [/global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock1/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock100/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock199/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock298/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock397/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock496/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy].
# [000308.75] [0/1] 03-05 05:28  MeshFFTWindow             INFO     Loading /pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/wmatrix_smooth_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy.
# [000308.82] [0/1] 03-05 05:28  BaseMatrix                INFO     Loading /pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/wmatrix_smooth_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy.
# [000313.88] [0/1] 03-05 05:28  ObservablesGaussianLikelihood INFO     Covariance matrix with 112 points built from 499 observations.
# [000313.88] [0/1] 03-05 05:28  ObservablesGaussianLikelihood INFO     ...resulting in a Hartlap 2007 factor of 0.7731.
# [000313.93] [0/1] 03-05 05:28  ObservablesGaussianLikelihood INFO     Covariance matrix with 112 points built from 499 observations, varying 12 parameters.
# [000313.93] [0/1] 03-05 05:28  ObservablesGaussianLikelihood INFO     ...resulting in a Percival 2014 factor of 1.2191.
# [000313.99] [0/1] 03-05 05:28  MinuitProfiler            INFO     Varied parameters: ['h', 'omega_cdm', 'omega_b', 'logA', 'b1', 'b2', 'bs', 'alpha0', 'alpha2', 'alpha4', 'sn0', 'sn2'].
# [000314.77] [0/1] 03-05 05:28  MinuitProfiler            INFO     Successfully jit input likelihood.
# [000314.77] [0/1] 03-05 05:28  TaskManager               INFO     Entering TaskManager with 1 workers.
# [000318.46] [0/1] 03-05 05:28  Profiles                  INFO     Saving ./results/profiles/LCDM/profile_ELG_LOPnotqso_GCcomb_z0.98.npy.
# Profiler finished
# [000318.46] [0/1] 03-05 05:28  Profiles                  INFO     Loading ./results/profiles/LCDM/profile_ELG_LOPnotqso_GCcomb_z0.98.npy.
# +-----------------------------------------+--------+---------+--------+
# | chi2 / (112 - 12) = 102.52 / 100 = 1.03 | varied | bestfit | error  |
# +-----------------------------------------+--------+---------+--------+
# |                    h                    |  True  |  0.688  | 0.022  |
# |                omega_cdm                |  True  |  0.126  | 0.012  |
# |                 omega_b                 |  True  | 0.02237 | 3.7e-4 |
# |                  logA                   |  True  |  3.00   |  0.15  |
# |                   b1                    |  True  |  1.26   |  0.12  |
# |                   b2                    |  True  |  -1.4   |  1.5   |
# |                   bs                    |  True  |   1.8   |  2.9   |
# |                 alpha0                  |  True  |   90.   |   63   |
# |                 alpha2                  |  True  |  -490   |  550   |
# |                 alpha4                  |  True  |   530   |  630   |
# |                   sn0                   |  True  |  -0.14  |  0.11  |
# |                   sn2                   |  True  |  -0.12  |  0.41  |
# +-----------------------------------------+--------+---------+--------+

# %%
observable = TracerPowerSpectrumMultipolesObservable(data= pk_fn, 
                                                    klim=klim, 
                                                    covariance = cov_fns,
                                                    theory=theory_el,
                                                    kin=np.arange(0.001, 0.35, 0.002),
                                                    wmatrix=wmatrix_fn)
likelihood = ObservablesGaussianLikelihood(observable, theory=theory_el)
print(-2*likelihood(**profiles.bestfit.choice(input=True)))
fig = observable.plot()
# Out:
# [000367.41] [0/1] 03-05 05:29  TracerPowerSpectrumMultipolesObservable INFO     Loading 1 file ['/pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/pkpoles_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy'].
# [000367.45] [0/1] 03-05 05:29  TracerPowerSpectrumMultipolesObservable INFO     Loading 499 files [/global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock1/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock100/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock199/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock298/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock397/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy, ..., /global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/EZmock/desipipe/v1/ffa/2pt/mock496/pk/pkpoles_ELG_LOP_GCcomb_z0.8-1.1_default_FKP_lin_nran10_cellsize6_boxsize9000.npy].
# [000395.88] [0/1] 03-05 05:29  MeshFFTWindow             INFO     Loading /pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/wmatrix_smooth_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy.
# [000395.94] [0/1] 03-05 05:29  BaseMatrix                INFO     Loading /pscratch/sd/s/shengyu/galaxies/catalogs/Y1/Abacus_v4_2/altmtl0/iron/mock0/LSScats/pk/wmatrix_smooth_ELG_LOPnotqso_GCcomb_0.8_1.1_default_FKP_lin_thetacut0.05.npy.
# [000399.95] [0/1] 03-05 05:29  ObservablesGaussianLikelihood INFO     Covariance matrix with 112 points built from 499 observations.
# [000399.96] [0/1] 03-05 05:29  ObservablesGaussianLikelihood INFO     ...resulting in a Hartlap 2007 factor of 0.7731.
# [000400.00] [0/1] 03-05 05:29  ObservablesGaussianLikelihood INFO     Covariance matrix with 112 points built from 499 observations, varying 12 parameters.
# [000400.00] [0/1] 03-05 05:29  ObservablesGaussianLikelihood INFO     ...resulting in a Percival 2014 factor of 1.2191.
# 102.5219503355733

# %%
# plot the posterior distribution
from desilike.samples import plotting

fig = plotting.plot_triangle_contours(profiles, params=['h','omega_cdm','logA'], filled=True)

# %%
catas_types = ['', '_realistic', '_failures']
labels = ['z', 'z_realistic','z_failures']
colors = ['black', 'C0', 'C1']

fig, ax = plt.subplots(3,1, figsize = (6,6), gridspec_kw={'height_ratios': [2, 1, 1], 'hspace': 0}, sharex=True)
for i, catas_type in enumerate(catas_types):
    catas_fn = pk_dir+f'pkpoles_{tracer}_{region}_{zmin}_{zmax}_default_FKP_lin5_thetacut0.05{catas_type}.txt'
    catas_pkl = np.loadtxt(catas_fn, dtype=complex)
    k = np.real(catas_pkl[:,1])[4:60]
    pk0 = np.real(catas_pkl[:,3])[4:60]
    pk2 = np.real(catas_pkl[:,4])[4:60]
    if i ==0:
        pk0_fiducial = pk0
        pk2_fiducial = pk2
        ax[0].plot(k, k*(pk0), label= 'z', color=colors[i])
        ax[0].plot(k, k*(pk2), color=colors[i])
        ax[0].fill_between(k, k*(pk0-std[:56]), k*((pk0)+std[:56]), color='grey', alpha=0.3)
        ax[0].fill_between(k, k*(pk2-std[56:112]), k*((pk2)+std[56:112]), color='grey', alpha=0.3)

    if i>0:
        ax[0].plot(k, k*(pk0), color=colors[i], label= labels[i])
        ax[0].plot(k, k*(pk2), color=colors[i])
        # ax[1].plot(k, pk0/pk0_fiducial, color=colors[i])
        # ax[2].plot(k, pk2/pk2_fiducial, color=colors[i])
        ax[1].plot(k, (pk0- pk0_fiducial)/std[:56], color=colors[i])
        ax[2].plot(k, (pk2 - pk2_fiducial)/std[56:112], color=colors[i])
        ax[i].plot(k, [0]*len(k), color='black', ls='-')
        ax[i].fill_between(k, -1, +1, color='grey', alpha=0.3)

    ax[0].legend()
    ax[0].set_ylim([120,550])
    # ax[i].grid(True)
    # plt.plot(k, k*pk2, label = sys_types[i])
plt.xlim([0.02,0.30])
plt.show()
